# %%
a = [10, 20, 30]
b = ["apple", "banana"]
c = [1, "hello", True]
d = []

# %%
a.append(5)

# %%
a
# Out:
# [10, 20, 30, 10, 4, 4, 5, 5, 5]

# %%
a[3]=10

# %%
a
# Out:
# [10, 20, 30, 10, 4, 4, 5, 5, 5]

# %%
len(a)
# Out:
# 9

# %%
sum(a)
# Out:
# 93

# %%
min(a)
# Out:
# 4

# %%
max(a)
# Out:
# 30

# %%
list(reversed(a))
# Out:
# [5, 5, 5, 4, 4, 10, 30, 20, 10]

# %%
a
# Out:
# [10, 20, 30, 10, 4, 4, 5, 5, 5]

# %%
sorted(a)
# Out:
# [4, 4, 5, 5, 5, 10, 10, 20, 30]

# %%
b
# Out:
# ['apple', 'banana']

# %%
b[1]
# Out:
# 'banana'

# %%
c
# Out:
# [1, 'hello', True]

# %%
c[1]
# Out:
# 'hello'

# %%
d
# Out:
# []

# %%
fruits = ["apple", "banana", "cherry", "orange", "grape", "strawberry",
    "peach", "pear", "pineapple",
    "mango", "kiwi", "watermelon",
    "blueberry", "lemon", "lime"]

# %%
len(fruits)
# Out:
# 15

# %%
for f in fruits:
  print(f)
# Out:
# apple
# banana
# cherry
# orange
# grape
# strawberry
# peach
# pear
# pineapple
# mango
# kiwi
# watermelon
# blueberry
# lemon
# lime

# %%
upper_fruits=[]
for fruit in fruits:
  upper_fruits.append(fruit.upper())

# %%
for i fruit in enumerate(fruits):
  print(f"i")
# Out:
#   File "/tmp/ipykernel_15019/1046371702.py", line 1
#     for i fruit in enumerate(fruits):
#           ^
# SyntaxError: invalid syntax

# %%
joseon_kings = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]

for i, name in enumerate(joseon_kings, start=1):
    print(f"{i}대왕 {name}")
# Out:
# 1대왕 태조
# 2대왕 정종
# 3대왕 태종
# 4대왕 세종
# 5대왕 문종
# 6대왕 단종
# 7대왕 세조
# 8대왕 예종
# 9대왕 성종
# 10대왕 연산군
# 11대왕 중종
# 12대왕 인종
# 13대왕 명종
# 14대왕 선조
# 15대왕 광해군
# 16대왕 인조
# 17대왕 효종
# 18대왕 현종
# 19대왕 숙종
# 20대왕 경종
# 21대왕 영조
# 22대왕 정조
# 23대왕 순조
# 24대왕 헌종
# 25대왕 철종
# 26대왕 고종
# 27대왕 순종

# %%
n = int(input("몇대왕이냐고? (1~27 입력): "))

if 1 <= n <= len(joseon_kings):
    print(f"{n}대왕은 {joseon_kings[n-1]} 입니다.")
else:
    print("범위를 벗어났어요. 1~27 사이로 입력해 주세요.")
# Out:
# 몇대왕이냐고? (1~27 입력): 3
# 3대왕은 태종 입니다.

# %%
joseon_kings = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]

for i, name in enumerate(joseon_kings, start=1):
  print(f"{i}대왕은 {name}입니다")
# Out:
# 1대왕은 태조입니다
# 2대왕은 정종입니다
# 3대왕은 태종입니다
# 4대왕은 세종입니다
# 5대왕은 문종입니다
# 6대왕은 단종입니다
# 7대왕은 세조입니다
# 8대왕은 예종입니다
# 9대왕은 성종입니다
# 10대왕은 연산군입니다
# 11대왕은 중종입니다
# 12대왕은 인종입니다
# 13대왕은 명종입니다
# 14대왕은 선조입니다
# 15대왕은 광해군입니다
# 16대왕은 인조입니다
# 17대왕은 효종입니다
# 18대왕은 현종입니다
# 19대왕은 숙종입니다
# 20대왕은 경종입니다
# 21대왕은 영조입니다
# 22대왕은 정조입니다
# 23대왕은 순조입니다
# 24대왕은 헌종입니다
# 25대왕은 철종입니다
# 26대왕은 고종입니다
# 27대왕은 순종입니다

# %%
n = int(input("몇대왕 입니까?"))

if 1 <= n <= len(joseon_kings):
  print(f"{n}대왕은 {joseon_kings[n-1]}입니다")
else:
  print("1~27중 입력해주세요")
# Out:
# 몇대왕 입니까?2
# 2대왕은 정종입니다

# %%
nn = input("왕의 이름은?")

if nn in joseon_kings:
  print(f"{nn}은 {joseon_kings.index(nn)+1}대 왕입니다")

else:
  print(f"{nn}왕은 없습니다")
# Out:
# 왕의 이름은?철종
# 철종은 25대 왕입니다

# %%
for i in list(reversed(joseon_kings)):
  print(i)
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조

# %%
for i in range(len(joseon_kings)-1,-1,-1):
  print(joseon_kings[i])
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조
